# %%
"""
Your task in this exercise has two steps:

- audit the OSMFILE and change the variable 'mapping' to reflect the changes needed to fix 
    the unexpected street types to the appropriate ones in the expected list.
    You have to add mappings only for the actual problems you find in this OSMFILE,
    not a generalized solution, since that may and will depend on the particular area you are auditing.
- write the update_name function, to actually fix the street name.
    The function takes a string with street name as an argument and should return the fixed name
    We have provided a simple test so that you see what exactly is expected
"""
import xml.etree.cElementTree as ET
from collections import defaultdict
import re
import pprint

OSMFILE = "C:\Users\Vijin\Udacity\Part 4\Project\Palm Beach County.osm"

#Regular expression to get the street type
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)


expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons"]

# This is the mapping dictionary which illustrates what Street Types need to be fixed
mapping = { "St": "Street",
            "St.": "Street",
            "Ave": "Avenue",
            "Rd.": "Road",
            "Rd": "Road",
            "Blvd.": "Boulevard",   
           "Blvd": "Boulevard",
           "Dr": "Drive",
           "Dr.": "Drive"
            }

#Filtering street types. All the inconsistent street types are filtered out
def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)
            
            
# Filtering postcodes. Postcodes starting with 334 are only considered valid            
def audit_post_code(postcode_types, postcode):
    if postcode.startswith("334"):
        postcode_types['valid'].add(postcode)
    else:
        postcode_types['invalid'].add(postcode)
        
        
# Filtering phone numbers. Phone numbers in xxx-xxx-xxxx are only considered valid     
def audit_phone(phone_types, phone):
    matchtel=re.match(r'\d{3}-\d{3}-\d{4}',phone)
    if matchtel:
        phone_types['valid'].add(phone)
    else:
        phone_types['invalid'].add(phone)        


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def is_postcode(elem):
    return (elem.attrib['k'] == "addr:postcode")

def is_phone(elem):
    return (elem.attrib['k'] == "phone")


def auditStreet(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
# Correct street type
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
            
    osm_file.close()
    return street_types

def auditPostCode(osmfile):
    osm_file = open(osmfile, "r")
    postcode_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
            
# Correct Post Code
                if is_postcode(tag):
                    audit_post_code(postcode_types, tag.attrib['v'])
    osm_file.close()
    return postcode_types

def auditPhone(osmfile):
    osm_file = open(osmfile, "r")
    phone_types = defaultdict(set)
    for event, elem in ET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
            
# Correct Telephone
                if is_phone(tag):
                    audit_phone(phone_types, tag.attrib['v'])
    osm_file.close()
    return phone_types


def update_name(name, mapping):

    # Updating Inconsistent street types
    for key,value in mapping.items():
        print 'Name, Key and Value is ', name," " , key, " ", value
        if key in name:
            updatedName=re.sub(key,value,name)
            print 'Updated Name is: ',updatedName
            break

    return updatedName

def update_postcode(pcodetypes):

    # Update Post code which starts with FL
    updatedPostCodeList=[]
    for key,value in pcodetypes.items():
        print 'Key and Value is ', key, " ", value
        if key == 'invalid':
            for item in iter(value):
                if item.startswith('FL'):
                    print 'Post code before update is ', item
                    updatedPostCode=re.sub('FL','',item)
                    updatedPostCode.replace(' ','')
                    updatedPostCodeList.append(updatedPostCode)
                    print 'Updated post code is ', updatedPostCode

    return updatedPostCodeList

def update_phone(phonetypes):
    
    #Update phone numbers in the following formats +1 xxx-xxx-xxxx, +1-xxx-xxx-xxxx, +1 (xxx)-xxx-xxxx to xxx-xxx-xxxx
    #Update phone numbers in the following format (xxx)-xxx-xxxx, (xxx) xxx-xxxx to xxx-xxx-xxxx
    updatedPhoneList=[]
    for key,value in phonetypes.items():
        if key == 'invalid':
            for item in iter(value):
                if item.startswith('+1'):
                    print 'Phone number before update is ', item
                    updatedPhone=re.sub(r'^(\+1\D?)','',item)
                    updatedPhone1=re.sub(r'[\(\)]','',updatedPhone)
                    updatedPhone2=re.sub(r'\s','-',updatedPhone1)
                    updatedPhoneList.append(updatedPhone2)
                    print 'Updated phone number is ', updatedPhone2
                
                elif item.startswith('('):
                    print 'Phone number before update is ', item
                    updatedPhone=re.sub(r'[\(\)]','',item)
                    updatedPhone1=re.sub(r'\s','-',updatedPhone)
                    updatedPhoneList.append(updatedPhone1)
                    print 'Updated phone number is ', updatedPhone1

    return updatedPhoneList
    

def test():
    st_types = auditStreet(OSMFILE)
    pcode_types=auditPostCode(OSMFILE)
    phone_types=auditPhone(OSMFILE)
   
    pprint.pprint(dict(pcode_types))
    pprint.pprint(dict(phone_types))
    update_postcode(pcode_types)
    update_phone(phone_types)

    for st_type, ways in st_types.iteritems():
        for name in ways:
            better_name = update_name(name, mapping)
            print name, "=>", better_name
            

if __name__ == '__main__':
    test()
# Out:
# Phone number before update is  +1 561-844-2601
# Updated phone number is  561-844-2601
# Phone number before update is  +1 877-750-2628
# Updated phone number is  877-750-2628
# Phone number before update is  (561) 612-7853
# Updated phone number is  561-612-7853
# Phone number before update is  (561) 640-5570
# Updated phone number is  561-640-5570
# Phone number before update is  (561) 972-9000
# Updated phone number is  561-972-9000
# Phone number before update is  +1 561 488 8000
# Updated phone number is  561-488-8000
# Phone number before update is  +1 954 480 9111
# Updated phone number is  954-480-9111
# Phone number before update is  (954) 943-2902
# Updated phone number is  954-943-2902
# Phone number before update is  +1 561 955 7100
# Updated phone number is  561-955-7100
# Phone number before update is  +1 561 737 7733
# Updated phone number is  561-737-7733
# Phone number before update is  +1 561 6225575
# Updated phone number is  561-6225575
# Phone number before update is  +1 (954) 609-2542
# Updated phone number is  954-609-2542
# Phone number before update is  (561) 659-4020
# Updated phone number is  561-659-4020
# Phone number before update is  +1 561 383 8000
# Updated phone number is  561-383-8000
# Phone number before update is  +1 561-659-7373
# Updated phone number is  561-659-7373
# Phone number before update is  +1 561 798 7110
# Updated phone number is  561-798-7110
# Phone number before update is  (561) 684-9400
# Updated phone number is  561-684-9400
# Phone number before update is  (561) 870-5913
# Updated phone number is  561-870-5913
# Phone number before update is  +1 561 582 9713
# Updated phone number is  561-582-9713
# Phone number before update is  +1 954 941 8300
# Updated phone number is  954-941-8300
# Phone number before update is  +1 561 798 8500
# Updated phone number is  561-798-8500
# Phone number before update is  (888) 798-8049
# Updated phone number is  888-798-8049
# Phone number before update is  +1-954-946-8200
# Updated phone number is  954-946-8200
# Phone number before update is  (561) 203-7438
# Updated phone number is  561-203-7438
# Phone number before update is  (561) 615-2301
# Updated phone number is  561-615-2301
# Phone number before update is  +1 561 863 3900
# Updated phone number is  561-863-3900
# Phone number before update is  +1-561-775-8775
# Updated phone number is  561-775-8775
# Phone number before update is  (561) 582-4468
# Updated phone number is  561-582-4468
# Phone number before update is  +1 (561) 432-4966
# Updated phone number is  561-432-4966
# Phone number before update is  +1-561-968-5105
# Updated phone number is  561-968-5105
# Phone number before update is  +1 561 996 6571
# Updated phone number is  561-996-6571
# Phone number before update is  (561) 793-1115
# Updated phone number is  561-793-1115
# Phone number before update is  (561) 795-6663
# Updated phone number is  561-795-6663
# Phone number before update is  +1 561 655 5511
# Updated phone number is  561-655-5511
# Phone number before update is  +1-561-292-2885
# Updated phone number is  561-292-2885
# Phone number before update is  +1 561-361-4888
# Updated phone number is  561-361-4888
# Phone number before update is  (561) 746-1180
# Updated phone number is  561-746-1180
# Phone number before update is  +1-561-687-0205
# Updated phone number is  561-687-0205
# Phone number before update is  +1 561 494 1900
# Updated phone number is  561-494-1900
# Phone number before update is  (561) 588-4488
# Updated phone number is  561-588-4488
# Phone number before update is  (561) 408-9800
# Updated phone number is  561-408-9800
# Phone number before update is  +1-954-974-1788
# Updated phone number is  954-974-1788
# Phone number before update is  +1 561-683-8300
# Updated phone number is  561-683-8300
# Phone number before update is  +1-561-738-9415
# Updated phone number is  561-738-9415
# Phone number before update is  (561) 203-2340
# Updated phone number is  561-203-2340
# Phone number before update is  (561) 988-0460
# Updated phone number is  561-988-0460
# Phone number before update is  +1-561-403-5372
# Updated phone number is  561-403-5372
# Phone number before update is  (561) 588-5208
# Updated phone number is  561-588-5208
# Phone number before update is  (561) 557-9144
# Updated phone number is  561-557-9144
# Phone number before update is  +1-954-812-3595
# Updated phone number is  954-812-3595
# Phone number before update is  +1 954 979 6401
# Updated phone number is  954-979-6401
# Phone number before update is  +1 (561) 395-5225
# Updated phone number is  561-395-5225
# Phone number before update is  (561-659-3880
# Updated phone number is  561-659-3880
# Phone number before update is  (561) 276-9334
# Updated phone number is  561-276-9334
# Phone number before update is  +1 863 902 3000
# Updated phone number is  863-902-3000
# Phone number before update is  (561) 272-5127
# Updated phone number is  561-272-5127
# Phone number before update is  +1 (561) 434-9098
# Updated phone number is  561-434-9098
# Phone number before update is  +1 561-624-6952
# Updated phone number is  561-624-6952
# Phone number before update is  +1 (954) 480-4200
# Updated phone number is  954-480-4200
# Phone number before update is  +1 (561) 969-6600
# Updated phone number is  561-969-6600
# Phone number before update is  +1 561 622 1411
# Updated phone number is  561-622-1411
# Phone number before update is  +1 561 498 4440
# Updated phone number is  561-498-4440
# Phone number before update is  (561) 688-9033
# Updated phone number is  561-688-9033
# Phone number before update is  +1 561-471-8876
# Updated phone number is  561-471-8876
# Phone number before update is  (561)738-0077
# Updated phone number is  561738-0077
# Phone number before update is  (561) 585-1885
# Updated phone number is  561-585-1885
# Phone number before update is  +1-561-733-7726
# Updated phone number is  561-733-7726
# Phone number before update is  +1 (800) 427-9104
# Updated phone number is  800-427-9104
# Phone number before update is  +1 561-616-0105
# Updated phone number is  561-616-0105
# Phone number before update is  +1-561-395-0593
# Updated phone number is  561-395-0593
# Phone number before update is  (561) 296-7621
# Updated phone number is  561-296-7621
# Phone number before update is  +1 561-747-8878
# Updated phone number is  561-747-8878
# Phone number before update is  +1 561-495-1144
# Updated phone number is  561-495-1144
# Phone number before update is  +1561-798-8899
# Updated phone number is  561-798-8899
# Phone number before update is  (561) 328-6429
# Updated phone number is  561-328-6429
# Phone number before update is  +1 561-406-6417
# Updated phone number is  561-406-6417
# Phone number before update is  (954) 933-7120
# Updated phone number is  954-933-7120
# Phone number before update is  (561) 330-0663
# Updated phone number is  561-330-0663
# Phone number before update is  +1 561-392-2500
# Updated phone number is  561-392-2500
# Phone number before update is  +1 954 974 0400
# Updated phone number is  954-974-0400
# Phone number before update is  +1 561 422 8262
# Updated phone number is  561-422-8262
# Phone number before update is  +1-561-370-7842
# Updated phone number is  561-370-7842
# Phone number before update is  (888) 710-3039
# Updated phone number is  888-710-3039
# Phone number before update is  (561) 793-0333
# Updated phone number is  561-793-0333
# Phone number before update is  +1 561 2780361
# Updated phone number is  561-2780361
# Phone number before update is  (561) 478-0783
# Updated phone number is  561-478-0783
# Phone number before update is  +1-844-338-5587
# Updated phone number is  844-338-5587
# Phone number before update is  +1-954-725-7783
# Updated phone number is  954-725-7783
# Phone number before update is  +1 561 880 0110
# Updated phone number is  561-880-0110
# Phone number before update is  (561) 249-0249
# Updated phone number is  561-249-0249
# Phone number before update is  +1 (561) 368-1560
# Updated phone number is  561-368-1560
# Phone number before update is  (561) 793-9980
# Updated phone number is  561-793-9980
# Phone number before update is  (561) 278-9590
# Updated phone number is  561-278-9590
# Phone number before update is  (954) 531-6168
# Updated phone number is  954-531-6168
# Phone number before update is  (754) 205-3166
# Updated phone number is  754-205-3166
# Phone number before update is  +1 954 344 3000
# Updated phone number is  954-344-3000
# Phone number before update is  +1-561-832-5196
# Updated phone number is  561-832-5196
# Phone number before update is  +1 561-330-3232
# Updated phone number is  561-330-3232
# Phone number before update is  +18005517217
# Updated phone number is  8005517217
# Phone number before update is  +1-561-582-5800
# Updated phone number is  561-582-5800
# Phone number before update is  (561) 689-1830
# Updated phone number is  561-689-1830
# Phone number before update is  +1 561-338-5031
# Updated phone number is  561-338-5031
# Phone number before update is  (954) 752-0333
# Updated phone number is  954-752-0333
# Phone number before update is  +1 561-582-9153
# Updated phone number is  561-582-9153
# Phone number before update is  +1 561 263 2234
# Updated phone number is  561-263-2234
# Phone number before update is  (561) 478-8852
# Updated phone number is  561-478-8852
# Phone number before update is  (561) 499-3559
# Updated phone number is  561-499-3559
# Phone number before update is  +1 561 582-9001
# Updated phone number is  561-582-9001
# Phone number before update is  (561) 795-4333
# Updated phone number is  561-795-4333
# Phone number before update is  (888) 392-5615
# Updated phone number is  888-392-5615
# Phone number before update is  +1-561-886-0470
# Updated phone number is  561-886-0470
# Phone number before update is  (561) 721-9333
# Updated phone number is  561-721-9333
# Phone number before update is  (561) 686-4300
# Updated phone number is  561-686-4300
# Phone number before update is  (561) 932-0050
# Updated phone number is  561-932-0050
# Phone number before update is  +1 (561) 393-7978
# Updated phone number is  561-393-7978
# Phone number before update is  (800) 863-2819
# Updated phone number is  800-863-2819
# Phone number before update is  +1-754-217-2621
# Updated phone number is  754-217-2621
# Phone number before update is  +1 561-650-1203
# Updated phone number is  561-650-1203
# Phone number before update is  +1-561-475-5255
# Updated phone number is  561-475-5255
# Phone number before update is  +1 561 547 7164
# Updated phone number is  561-547-7164
# Phone number before update is  +1-561-204-5033
# Updated phone number is  561-204-5033
# Phone number before update is  +1 (954) 480-4422
# Updated phone number is  954-480-4422
# Phone number before update is  +1 561 844 6300
# Updated phone number is  561-844-6300
# Phone number before update is  +1 561-655-6333
# Updated phone number is  561-655-6333
# Phone number before update is  +1 561 582-2585
# Updated phone number is  561-582-2585
# Phone number before update is  (561) 547-8860
# Updated phone number is  561-547-8860
# Phone number before update is  (561) 478-3574
# Updated phone number is  561-478-3574
# Phone number before update is  (561) 585-6104
# Updated phone number is  561-585-6104
# Phone number before update is  (561) 965-7300
# Updated phone number is  561-965-7300
# Phone number before update is  +1 (561) 368-1789
# Updated phone number is  561-368-1789
# Phone number before update is  (561) 684-3015
# Updated phone number is  561-684-3015
# Phone number before update is  (561) 562-8039
# Updated phone number is  561-562-8039
# Phone number before update is  (954) 510-8300
# Updated phone number is  954-510-8300
# Phone number before update is  +1-561-465-3446
# Updated phone number is  561-465-3446
# Phone number before update is  +1 561-848-1188
# Updated phone number is  561-848-1188
# Phone number before update is  +1 (561) 515-4400
# Updated phone number is  561-515-4400
# Phone number before update is  +1 561 588-4133
# Updated phone number is  561-588-4133
# Phone number before update is  +1-561-208-1691
# Updated phone number is  561-208-1691
# Phone number before update is  (561) 204-3012
# Updated phone number is  561-204-3012
# Phone number before update is  (561) 683-4121
# Updated phone number is  561-683-4121
# Phone number before update is  +1 561-845-8800
# Updated phone number is  561-845-8800
# Phone number before update is  +1-561-832-4918
# Updated phone number is  561-832-4918
# Phone number before update is  +1 561 249-1568
# Updated phone number is  561-249-1568
# Phone number before update is  +1 561 273-4130
# Updated phone number is  561-273-4130
# Phone number before update is  +1-561-203-2643
# Updated phone number is  561-203-2643
# Phone number before update is  +1 561-433-2898
# Updated phone number is  561-433-2898
# Phone number before update is  +1561-922-0206
# Updated phone number is  561-922-0206
# Phone number before update is  (561-233-7200
# Updated phone number is  561-233-7200
